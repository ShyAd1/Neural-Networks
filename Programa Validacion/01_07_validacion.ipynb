# %% [markdown]
# # Ejercicio realizado por:
# ## Hernández Valdivia Adair
# ## Ortiz Barron Moises Sebastian

# %% [markdown]
# # Validación
#
# (4 puntos totales)
#
# Hasta el momento hemos logrado entrenar la red, es decir, encontrar los pesos tal que se reduce el error entre la salida de la red y la salida esperada. Con los pesos entrenados, la red pude predecir la clase que corresponde a una entrada que no ha visto. Este proceso de predicción conocido como inferencia es la parte más interesante de las redes ya que permite generalizar su uso a casos no vistos. Sin embargo, durante el entrenamiento se puede suscitar un fenómeno conocido como sobre-ajuste (overfitting), donde la red reduce de manera adecuada la pérdida con respecto a los datos de entrenamiento, pero al momento de encontrarse con ejemplos desconocidos, ésta tiene un rendimiento pobre. Este efecto es contrario, por que buscamos **generalizar** el rendimiento de tal forma que clasifique bien ejemplos que no han sido vistos.
#
# Para saber que tan bien está generalizando la red se realiza un proceso de validación. En este proceso de validación se verifican las predicciones de la red en un conjunto de datos de validación. También haremos uso de *dropout*, una técnica de regularización que ayuda a reducir el sobre-ajuste.
#
#
# @juan1rving

# %%
# Cargamos paquetes necesarios
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms

# helper was developed by Udacity under MIT license. Paquete disponible en el repositorio del curso.
import helper

# %% [markdown]
# ## Conjunto de datos (Dataset)
#
# Para este ejemplo utilizaremos el Fashion MNIST. Este dataset esta constituido por imágenes de 28 x 28 pixeles y cada imagen contiene prendas como ropa o zapatos.

# %%
# Semilla para reproducibilidad
# NOTE: No modificar esta sección, es importante para la reproducibilidad de los resultados.
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

# Definimos una transformación de los datos
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Descargamos el conjunto completo de entrenamiento
full_trainset = datasets.FashionMNIST(
    'F_MNIST_data/', download=True, train=True, transform=transform
)

# Partición reproducible en subconjuntos (por ejemplo 80% train, 20% validación)
train_size = int(0.8 * len(full_trainset))
val_size = len(full_trainset) - train_size

split_generator = torch.Generator().manual_seed(seed)
trainset, validationset = torch.utils.data.random_split(
    full_trainset, [train_size, val_size], generator=split_generator
)

# DataLoaders reproducibles
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=64, shuffle=True, generator=torch.Generator().manual_seed(seed)
)
validationloader = torch.utils.data.DataLoader(
    validationset, batch_size=64, shuffle=False
)

# %% [markdown]
# ## Red Neuronal
#
# En esta ocasión, construiremos la red de forma más general, donde las capas ocultas se generarán a partir de un vector que indica el número de capas y el número de nodos de cada capa. Haremos uso del módulo *nn.ModuleList* que nos permitirá crear un número arbitrario de capas. En cierta forma *nn.ModuleList* se comporta como una lista simple de python.

# %%
#NOTE: No modificar esta sección, es importante para la reproducibilidad de los resultados.
class RedNeuronal(nn.Module):
    def __init__(self, input_size, output_size, hidden_layers, drop_p = 0.5):
        '''
        Construye una red de tamaño arbitrario.
        
        Parámetros:
        input_size: cantidad de elementos en la entrada
        output_size: cantidada de elementos en la salida 
        hidden_layers: cantidad de elementos por cada capa oculta
        drop_p: probabilidad de "tirar" (drop) una neurona [0,1] 
        '''
        # llamamos al constructor de la superclase
        super().__init__()
        
        # Agregamos la primera capa
        self.hidden_layers = nn.ModuleList([nn.Linear(input_size, hidden_layers[0])])
        
        # agregamos cada una de las capas, zip empareja el número de entradas con las salidas
        layer_sizes = zip(hidden_layers[:-1], hidden_layers[1:])
        self.hidden_layers.extend([nn.Linear(h1, h2) for h1, h2 in layer_sizes])
        
        # agregamos la capa de salida final de la red
        self.output = nn.Linear(hidden_layers[-1], output_size)
        
        # Incluimos drop-out en la red
        self.dropout = nn.Dropout(p=drop_p)
        
    def forward(self, x):
        ''' Pase hacia adelante en la red, el regreso son las probabilidades en el dominio log '''
        
        # Hacemos un pase frontal en cada una de las capas ocultas, 
        # La funció de activación es un RELU combinado con dropout
        for linear in self.hidden_layers:
            x = F.relu(linear(x))
            x = self.dropout(x)
        
        x = self.output(x)
        
        return F.log_softmax(x, dim=1)

# %% [markdown]
# ## Entrenamiento
#
# Ahora entrenaremos la red tal cual lo hemos visto en sesiones previas.
#
# La pérdida (loss) nos indica que tan bien o mal está clasificando nuestra red. Dado que estamos utilizando el dominio log para calcular las salidas de la red, utilizaremos el criterio negative log loss *nn.NLLLoss()*. Como optimizador utilzaremos SGD optimizer, el cual permite intercambiar los lotes de entrenamiento para reducir la caida en minimos locales.

# %%
# NOTE: Si lo desea puede modificar los hiperparámetros, pero no es necesario para obtener buenos resultados.
tasa_de_aprendizaje = 0.01
probabilidad_de_dropout = 0.2

# Tambien si lo desea puede modificar la arquitectura de la red.
model = RedNeuronal(784, 10, [516, 256], drop_p=probabilidad_de_dropout)
criterion = nn.NLLLoss()

# NOTE: Puede cambiar el optimizador, pero ADAM no esta permitido.
# Las alternativas son: optim.SGD, optim.RMSprop, optim.Adagrad, optim.Adadelta, optim.Adamax, optim.ASGD, optim.LBFGS
optimizer = optim.SGD(model.parameters(), lr=tasa_de_aprendizaje)

# %% [markdown]
# Ahora programaremos la validación. En esta etapa se mide la exactitud de la red en el conjunto de validación a fin de ver que tan bien está generalizando la red. Como estamos utilizando drop out durante el entrenamiento al momento de hacer una inferencia este proceso se debe desactivar. Afortunadamente pytorch provee dos modos de funcionamiento para la red: entrenamiento o evaluación, model.train() y model.eval() respectivamente.
#
# Recuerda que la validación se verá como sigue:
# ```
#     with torch.no_grad(): # se desactivan los gradientes
#         test_loss, accuracy = validation(model, validationloader, criterion) #se llama a la funcion de validación
# ```

# %%
# Implementamos una función de validación.
def validation(model, validationloader, criterion):
    test_loss = 0
    accuracy = 0
    for images, labels in validationloader:

        images.resize_(images.shape[0], 784)

        output = model.forward(images)
        test_loss += criterion(output, labels).item()

        ps = torch.exp(output)
        equality = (labels.data == ps.max(dim=1)[1])
        accuracy += equality.type(torch.FloatTensor).mean()
    
    return test_loss, accuracy

# %% [markdown]
# Implementación del entrenamiento y validación por épocas

# %%
# Hiperparámetros
epochs = 2
steps = 0
running_loss = 0
print_every = 40

# %%
# Historial de pérdidas
train_losses = []
val_losses = []

for e in range(epochs):
    model.train()
    epoch_train_loss = 0

    for images, labels in trainloader:
        steps += 1

        # Aplanar imágenes
        images = images.view(images.size(0), 784)

        optimizer.zero_grad()

        output = model.forward(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        epoch_train_loss += loss.item()

        if steps % print_every == 0:
            #TODO: (1 pt) desactiva los gradientes y calcula la pérdida y exactitud en el conjunto de validación )
            with torch.no_grad():
                test_loss, accuracy = validation(model, validationloader, criterion)

            print("Epoch: {}/{}.. ".format(e + 1, epochs),
                  "Pérdida de entrenamiento: {:.3f}.. ".format(running_loss / print_every),
                  "Pérdida de validación: {:.3f}.. ".format(test_loss / len(validationloader)),
                  "Exactitud de validación: {:.3f}".format(accuracy / len(validationloader)))

            running_loss = 0
            model.train()

    # Guardar pérdidas por época
    model.eval()
    with torch.no_grad():
        test_loss, accuracy = validation(model, validationloader, criterion)

    train_losses.append(epoch_train_loss / len(trainloader))
    val_losses.append(test_loss / len(validationloader))
# Out:
# Epoch: 1/2..  Pérdida de entrenamiento: 2.227..  Pérdida de validación: 2.144..  Exactitud de validación: 0.385
# Epoch: 1/2..  Pérdida de entrenamiento: 2.038..  Pérdida de validación: 1.924..  Exactitud de validación: 0.446
# Epoch: 1/2..  Pérdida de entrenamiento: 1.789..  Pérdida de validación: 1.649..  Exactitud de validación: 0.531
# Epoch: 1/2..  Pérdida de entrenamiento: 1.515..  Pérdida de validación: 1.397..  Exactitud de validación: 0.590
# Epoch: 1/2..  Pérdida de entrenamiento: 1.322..  Pérdida de validación: 1.222..  Exactitud de validación: 0.628
# Epoch: 1/2..  Pérdida de entrenamiento: 1.156..  Pérdida de validación: 1.090..  Exactitud de validación: 0.659
# Epoch: 1/2..  Pérdida de entrenamiento: 1.048..  Pérdida de validación: 1.010..  Exactitud de validación: 0.653
# Epoch: 1/2..  Pérdida de entrenamiento: 0.970..  Pérdida de validación: 0.945..  Exactitud de validación: 0.667
# Epoch: 1/2..  Pérdida de entrenamiento: 0.934..  Pérdida de validación: 0.894..  Exactitud de validación: 0.697
# Epoch: 1/2..  Pérdida de entrenamiento: 0.865..  Pérdida de validación: 0.853..  Exactitud de validación: 0.705
# Epoch: 1/2..  Pérdida de entrenamiento: 0.807..  Pérdida de validación: 0.820..  Exactitud de validación: 0.712
# Epoch: 1/2..  Pérdida de entrenamiento: 0.806..  Pérdida de validación: 0.796..  Exactitud de validación: 0.720
# Epoch: 1/2..  Pérdida de entrenamiento: 0.769..  Pérdida de validación: 0.779..  Exactitud de validación: 0.720
# Epoch: 1/2..  Pérdida de entrenamiento: 0.719..  Pérdida de validación: 0.755..  Exactitud de validación: 0.729
# Epoch: 1/2..  Pérdida de entrenamiento: 0.701..  Pérdida de validación: 0.740..  Exactitud de validación: 0.734
# Epoch: 1/2..  Pérdida de entrenamiento: 0.730..  Pérdida de validación: 0.723..  Exactitud de validación: 0.735
# Epoch: 1/2..  Pérdida de entrenamiento: 0.719..  Pérdida de validación: 0.716..  Exactitud de validación: 0.743
# Epoch: 1/2..  Pérdida de entrenamiento: 0.674..  Pérdida de validación: 0.698..  Exactitud de validación: 0.744
# Epoch: 2/2..  Pérdida de entrenamiento: 0.684..  Pérdida de validación: 0.689..  Exactitud de validación: 0.749
# Epoch: 2/2..  Pérdida de entrenamiento: 0.663..  Pérdida de validación: 0.684..  Exactitud de validación: 0.753
# Epoch: 2/2..  Pérdida de entrenamiento: 0.660..  Pérdida de validación: 0.670..  Exactitud de validación: 0.756
# Epoch: 2/2..  Pérdida de entrenamiento: 0.670..  Pérdida de validación: 0.663..  Exactitud de validación: 0.757
# Epoch: 2/2..  Pérdida de entrenamiento: 0.649..  Pérdida de validación: 0.658..  Exactitud de validación: 0.756
# Epoch: 2/2..  Pérdida de entrenamiento: 0.651..  Pérdida de validación: 0.647..  Exactitud de validación: 0.763
# Epoch: 2/2..  Pérdida de entrenamiento: 0.617..  Pérdida de validación: 0.642..  Exactitud de validación: 0.766
# Epoch: 2/2..  Pérdida de entrenamiento: 0.615..  Pérdida de validación: 0.635..  Exactitud de validación: 0.769
# Epoch: 2/2..  Pérdida de entrenamiento: 0.621..  Pérdida de validación: 0.625..  Exactitud de validación: 0.774
# Epoch: 2/2..  Pérdida de entrenamiento: 0.624..  Pérdida de validación: 0.624..  Exactitud de validación: 0.773
# Epoch: 2/2..  Pérdida de entrenamiento: 0.605..  Pérdida de validación: 0.615..  Exactitud de validación: 0.776
# Epoch: 2/2..  Pérdida de entrenamiento: 0.613..  Pérdida de validación: 0.606..  Exactitud de validación: 0.780
# Epoch: 2/2..  Pérdida de entrenamiento: 0.580..  Pérdida de validación: 0.606..  Exactitud de validación: 0.781
# Epoch: 2/2..  Pérdida de entrenamiento: 0.600..  Pérdida de validación: 0.600..  Exactitud de validación: 0.780
# Epoch: 2/2..  Pérdida de entrenamiento: 0.577..  Pérdida de validación: 0.594..  Exactitud de validación: 0.785
# Epoch: 2/2..  Pérdida de entrenamiento: 0.593..  Pérdida de validación: 0.588..  Exactitud de validación: 0.789
# Epoch: 2/2..  Pérdida de entrenamiento: 0.589..  Pérdida de validación: 0.591..  Exactitud de validación: 0.789
# Epoch: 2/2..  Pérdida de entrenamiento: 0.557..  Pérdida de validación: 0.582..  Exactitud de validación: 0.796
# Epoch: 2/2..  Pérdida de entrenamiento: 0.563..  Pérdida de validación: 0.576..  Exactitud de validación: 0.795

# %%
# Gráfica de pérdidas
plt.figure(figsize=(8, 5))
plt.plot(range(1, epochs + 1), train_losses, marker='o', label='Train loss')
plt.plot(range(1, epochs + 1), val_losses, marker='s', label='Validation loss')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.title('Pérdida de entrenamiento vs validación')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## Inferencia
#
# Ahora que ya hemos entrenado la red vamos a probar cual es su rendimiento en la clasificación de las prendas de vestir.

# %%
# Probemos la red!
model.eval()

dataiter = iter(validationloader)
images, labels = next(dataiter)
img = images[0]
# Aplanamos la imagenes
img = img.view(1, 784)

# Estimamos para cada imagen la probabilidad de pertenencia a una clase (softmax)
with torch.no_grad():
    output = model.forward(img)

ps = torch.exp(output)

# Graficamos
helper.view_classify(img.view(1, 28, 28), ps, version='Fashion')

# %% [markdown]
# ## Actividad:
#
# Realiza lo siguiente:
#
# Entrena el modelo para que:
# 1) (1 pt) Alcances una exactitude de validación superior al 87% (Coloca aqui los hiperparámetros que usaste)
# 2) (2 pt) Alcanza un sobre ajuste de la red (se debe mostrar sobre la gráfica) Esto nos indicará el punto a partir del cual ya no conviene seguir entrenando.

# %% [markdown]
# ### 1. Mejorar el modelo a una validacion mayor al 87%
#
# Como la normalizacion no se puede modificar, se mejoraron los siguientes valores:
# - Epocas de 2 a 5
# - Cambio de optimizador de SGD a Adagrad
# - Arquitectura con capas ocultas [512, 256, 128]

# %%
# Hiperparámetros
epochs = 5
steps = 0
running_loss = 0
print_every = 40

# NOTE: Si lo desea puede modificar los hiperparámetros, pero no es necesario para obtener buenos resultados.
tasa_de_aprendizaje = 0.01
probabilidad_de_dropout = 0.1

# Tambien si lo desea puede modificar la arquitectura de la red.
model = RedNeuronal(784, 10, [512, 256, 128], drop_p=probabilidad_de_dropout)
criterion = nn.NLLLoss()

# NOTE: Puede cambiar el optimizador, pero ADAM no esta permitido.
# Las alternativas son: optim.SGD, optim.RMSprop, optim.Adagrad, optim.Adadelta, optim.Adamax, optim.ASGD, optim.LBFGS
optimizer = optim.Adagrad(model.parameters(), lr=tasa_de_aprendizaje)

# %%
# Historial de pérdidas
train_losses = []
val_losses = []

for e in range(epochs):
    model.train()
    epoch_train_loss = 0

    for images, labels in trainloader:
        steps += 1

        # Aplanar imágenes
        images = images.view(images.size(0), 784)

        optimizer.zero_grad()

        output = model.forward(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        epoch_train_loss += loss.item()

        if steps % print_every == 0:
            #TODO: (1 pt) desactiva los gradientes y calcula la pérdida y exactitud en el conjunto de validación )
            with torch.no_grad():
                test_loss, accuracy = validation(model, validationloader, criterion)
            
            print("Epoch: {}/{}.. ".format(e + 1, epochs),
                  "Pérdida de entrenamiento: {:.3f}.. ".format(running_loss / print_every),
                  "Pérdida de validación: {:.3f}.. ".format(test_loss / len(validationloader)),
                  "Exactitud de validación: {:.3f}".format(accuracy / len(validationloader)))

            running_loss = 0
            model.train()

    # Guardar pérdidas por época
    model.eval()
    with torch.no_grad():
        test_loss, accuracy = validation(model, validationloader, criterion)

    train_losses.append(epoch_train_loss / len(trainloader))
    val_losses.append(test_loss / len(validationloader))
# Out:
# Epoch: 1/5..  Pérdida de entrenamiento: 1.329..  Pérdida de validación: 0.787..  Exactitud de validación: 0.701
# Epoch: 1/5..  Pérdida de entrenamiento: 0.730..  Pérdida de validación: 0.685..  Exactitud de validación: 0.720
# Epoch: 1/5..  Pérdida de entrenamiento: 0.650..  Pérdida de validación: 0.628..  Exactitud de validación: 0.764
# Epoch: 1/5..  Pérdida de entrenamiento: 0.573..  Pérdida de validación: 0.565..  Exactitud de validación: 0.793
# Epoch: 1/5..  Pérdida de entrenamiento: 0.562..  Pérdida de validación: 0.568..  Exactitud de validación: 0.788
# Epoch: 1/5..  Pérdida de entrenamiento: 0.524..  Pérdida de validación: 0.520..  Exactitud de validación: 0.814
# Epoch: 1/5..  Pérdida de entrenamiento: 0.538..  Pérdida de validación: 0.554..  Exactitud de validación: 0.791
# Epoch: 5/5..  Pérdida de entrenamiento: 0.309..  Pérdida de validación: 0.345..  Exactitud de validación: 0.879
# Epoch: 5/5..  Pérdida de entrenamiento: 0.291..  Pérdida de validación: 0.347..  Exactitud de validación: 0.875
# Epoch: 5/5..  Pérdida de entrenamiento: 0.313..  Pérdida de validación: 0.345..  Exactitud de validación: 0.876
# Epoch: 5/5..  Pérdida de entrenamiento: 0.285..  Pérdida de validación: 0.341..  Exactitud de validación: 0.876
# Epoch: 5/5..  Pérdida de entrenamiento: 0.314..  Pérdida de validación: 0.343..  Exactitud de validación: 0.875
# Epoch: 5/5..  Pérdida de entrenamiento: 0.302..  Pérdida de validación: 0.342..  Exactitud de validación: 0.877
# Epoch: 5/5..  Pérdida de entrenamiento: 0.290..  Pérdida de validación: 0.342..  Exactitud de validación: 0.875
# Epoch: 5/5..  Pérdida de entrenamiento: 0.309..  Pérdida de validación: 0.341..  Exactitud de validación: 0.875
# Epoch: 5/5..  Pérdida de entrenamiento: 0.298..  Pérdida de validación: 0.346..  Exactitud de validación: 0.876
# Epoch: 5/5..  Pérdida de entrenamiento: 0.311..  Pérdida de validación: 0.337..  Exactitud de validación: 0.879

# %%
# Gráfica de pérdidas
plt.figure(figsize=(8, 5))
plt.plot(range(1, epochs + 1), train_losses, marker='o', label='Train loss')
plt.plot(range(1, epochs + 1), val_losses, marker='s', label='Validation loss')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.title('Pérdida de entrenamiento vs validación')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Probemos la red!
model.eval()

dataiter = iter(validationloader)
images, labels = next(dataiter)
img = images[0]
# Aplanamos la imagenes
img = img.view(1, 784)

# Estimamos para cada imagen la probabilidad de pertenencia a una clase (softmax)
with torch.no_grad():
    output = model.forward(img)

ps = torch.exp(output)

# Graficamos
helper.view_classify(img.view(1, 28, 28), ps, version='Fashion')

# %% [markdown]
# ### 2. Sobre ajustar el modelo
#
# Se para sobre ajuste se usaron los siguientes valores:
# - Epocas = 5
# - Tasa = 0.1
# - Dropout = 0
# - Optimizador Adagrad

# %%
# Hiperparámetros
epochs = 20
steps = 0
running_loss = 0
print_every = 40

# NOTE: Si lo desea puede modificar los hiperparámetros, pero no es necesario para obtener buenos resultados.
tasa_de_aprendizaje = 0.1
probabilidad_de_dropout = 0

# Tambien si lo desea puede modificar la arquitectura de la red.
model = RedNeuronal(784, 10, [1024, 512], drop_p=probabilidad_de_dropout)
criterion = nn.NLLLoss()

# NOTE: Puede cambiar el optimizador, pero ADAM no esta permitido.
# Las alternativas son: optim.SGD, optim.RMSprop, optim.Adagrad, optim.Adadelta, optim.Adamax, optim.ASGD, optim.LBFGS
optimizer = optim.Adagrad(model.parameters(), lr=tasa_de_aprendizaje)

# %%
# Historial de pérdidas
train_losses = []
val_losses = []

for e in range(epochs):
    model.train()
    epoch_train_loss = 0

    for images, labels in trainloader:
        steps += 1

        # Aplanar imágenes
        images = images.view(images.size(0), 784)

        optimizer.zero_grad()

        output = model.forward(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        epoch_train_loss += loss.item()

        if steps % print_every == 0:
            #TODO: (1 pt) desactiva los gradientes y calcula la pérdida y exactitud en el conjunto de validación )
            with torch.no_grad():
                test_loss, accuracy = validation(model, validationloader, criterion)

            print("Epoch: {}/{}.. ".format(e + 1, epochs),
                  "Pérdida de entrenamiento: {:.3f}.. ".format(running_loss / print_every),
                  "Pérdida de validación: {:.3f}.. ".format(test_loss / len(validationloader)),
                  "Exactitud de validación: {:.3f}".format(accuracy / len(validationloader)))

            running_loss = 0
            model.train()

    # Guardar pérdidas por época
    model.eval()
    with torch.no_grad():
        test_loss, accuracy = validation(model, validationloader, criterion)

    train_losses.append(epoch_train_loss / len(trainloader))
    val_losses.append(test_loss / len(validationloader))
# Out:
# Epoch: 1/20..  Pérdida de entrenamiento: 271.820..  Pérdida de validación: 2.785..  Exactitud de validación: 0.627
# Epoch: 1/20..  Pérdida de entrenamiento: 2.006..  Pérdida de validación: 1.882..  Exactitud de validación: 0.654
# Epoch: 1/20..  Pérdida de entrenamiento: 1.936..  Pérdida de validación: 1.340..  Exactitud de validación: 0.679
# Epoch: 1/20..  Pérdida de entrenamiento: 0.916..  Pérdida de validación: 1.041..  Exactitud de validación: 0.724
# Epoch: 1/20..  Pérdida de entrenamiento: 2.252..  Pérdida de validación: 1.102..  Exactitud de validación: 0.728
# Epoch: 1/20..  Pérdida de entrenamiento: 0.830..  Pérdida de validación: 1.013..  Exactitud de validación: 0.746
# Epoch: 1/20..  Pérdida de entrenamiento: 1.639..  Pérdida de validación: 0.929..  Exactitud de validación: 0.724
# Epoch: 1/20..  Pérdida de entrenamiento: 0.773..  Pérdida de validación: 0.764..  Exactitud de validación: 0.766
# Epoch: 1/20..  Pérdida de entrenamiento: 0.757..  Pérdida de validación: 0.729..  Exactitud de validación: 0.761
# Epoch: 1/20..  Pérdida de entrenamiento: 0.850..  Pérdida de validación: 0.734..  Exactitud de validación: 0.769
# Epoch: 1/20..  Pérdida de entrenamiento: 0.684..  Pérdida de validación: 0.684..  Exactitud de validación: 0.771
# Epoch: 1/20..  Pérdida de entrenamiento: 0.584..  Pérdida de validación: 0.671..  Exactitud de validación: 0.780
# Epoch: 1/20..  Pérdida de entrenamiento: 0.596..  Pérdida de validación: 0.677..  Exactitud de validación: 0.781
# Epoch: 1/20..  Pérdida de entrenamiento: 0.670..  Pérdida de validación: 0.634..  Exactitud de validación: 0.796
# Epoch: 1/20..  Pérdida de entrenamiento: 0.592..  Pérdida de validación: 0.636..  Exactitud de validación: 0.792
# Epoch: 1/20..  Pérdida de entrenamiento: 0.675..  Pérdida de validación: 0.711..  Exactitud de validación: 0.794
# Epoch: 1/20..  Pérdida de entrenamiento: 0.586..  Pérdida de validación: 0.646..  Exactitud de validación: 0.804
# Epoch: 1/20..  Pérdida de entrenamiento: 0.522..  Pérdida de validación: 0.658..  Exactitud de validación: 0.794
# Epoch: 2/20..  Pérdida de entrenamiento: 0.585..  Pérdida de validación: 0.643..  Exactitud de validación: 0.809
# Epoch: 19/20..  Pérdida de entrenamiento: 0.246..  Pérdida de validación: 0.442..  Exactitud de validación: 0.873
# Epoch: 20/20..  Pérdida de entrenamiento: 0.236..  Pérdida de validación: 0.441..  Exactitud de validación: 0.875
# Epoch: 20/20..  Pérdida de entrenamiento: 0.238..  Pérdida de validación: 0.444..  Exactitud de validación: 0.877
# Epoch: 20/20..  Pérdida de entrenamiento: 0.241..  Pérdida de validación: 0.446..  Exactitud de validación: 0.877
# Epoch: 20/20..  Pérdida de entrenamiento: 0.232..  Pérdida de validación: 0.445..  Exactitud de validación: 0.875
# Epoch: 20/20..  Pérdida de entrenamiento: 0.236..  Pérdida de validación: 0.444..  Exactitud de validación: 0.876
# Epoch: 20/20..  Pérdida de entrenamiento: 0.222..  Pérdida de validación: 0.445..  Exactitud de validación: 0.877
# Epoch: 20/20..  Pérdida de entrenamiento: 0.220..  Pérdida de validación: 0.446..  Exactitud de validación: 0.876
# Epoch: 20/20..  Pérdida de entrenamiento: 0.220..  Pérdida de validación: 0.444..  Exactitud de validación: 0.874
# Epoch: 20/20..  Pérdida de entrenamiento: 0.237..  Pérdida de validación: 0.452..  Exactitud de validación: 0.870
# Epoch: 20/20..  Pérdida de entrenamiento: 0.245..  Pérdida de validación: 0.438..  Exactitud de validación: 0.872
# Epoch: 20/20..  Pérdida de entrenamiento: 0.239..  Pérdida de validación: 0.434..  Exactitud de validación: 0.876
# Epoch: 20/20..  Pérdida de entrenamiento: 0.231..  Pérdida de validación: 0.436..  Exactitud de validación: 0.875
# Epoch: 20/20..  Pérdida de entrenamiento: 0.236..  Pérdida de validación: 0.450..  Exactitud de validación: 0.875
# Epoch: 20/20..  Pérdida de entrenamiento: 0.247..  Pérdida de validación: 0.441..  Exactitud de validación: 0.877
# Epoch: 20/20..  Pérdida de entrenamiento: 0.223..  Pérdida de validación: 0.441..  Exactitud de validación: 0.876
# Epoch: 20/20..  Pérdida de entrenamiento: 0.247..  Pérdida de validación: 0.452..  Exactitud de validación: 0.870
# Epoch: 20/20..  Pérdida de entrenamiento: 0.254..  Pérdida de validación: 0.436..  Exactitud de validación: 0.875
# Epoch: 20/20..  Pérdida de entrenamiento: 0.244..  Pérdida de validación: 0.435..  Exactitud de validación: 0.875
# Epoch: 20/20..  Pérdida de entrenamiento: 0.268..  Pérdida de validación: 0.448..  Exactitud de validación: 0.874

# %%
# Gráfica de pérdidas
plt.figure(figsize=(8, 5))
plt.plot(range(1, epochs + 1), train_losses, marker='o', label='Train loss')
plt.plot(range(1, epochs + 1), val_losses, marker='s', label='Validation loss')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.title('Pérdida de entrenamiento vs validación')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Probemos la red!
model.eval()

dataiter = iter(validationloader)
images, labels = next(dataiter)
img = images[0]
# Aplanamos la imagenes
img = img.view(1, 784)

# Estimamos para cada imagen la probabilidad de pertenencia a una clase (softmax)
with torch.no_grad():
    output = model.forward(img)

ps = torch.exp(output)

# Graficamos
helper.view_classify(img.view(1, 28, 28), ps, version='Fashion')
